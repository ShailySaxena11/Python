# %%
<!DOCTYPE html>
<html>
<head>
	<title>Agarwal Toal Kanta Receipt</title>
	<style>
		* {
			box-sizing: border-box;
			margin: 0;
			padding: 0;
		}
		body {
			width: 1024px;
			height: 768px;
			padding: 20px;
			font-family: Arial, sans-serif;
		}
		h2, h3 {
			text-align: center;
		}
		hr {
			border: 1px solid black;
			margin: 10px 0;
		}
		table {
			border-collapse: collapse;
			margin: 10px 0;
			width: 100%;
		}
		th, td {
			border: 1px solid black;
			padding: 5px;
			text-align: center;
		}
	</style>
</head>
<body>
	<h2>Sanjana Cold Storage Pvt. Ltd.</h2>
	<p>Sanjay Nagar Cat Road (Rau)</p>
	<p>Tr. No:</p>
	<p>Vehicle No: MP 09 LQ 0174</p>
	<p>Material:</p>
	<p>Customer:</p>
	<p>Remark:</p>
	<hr>
	<p>Last Wt. for this vehicle: kg Date: 06/03/2023 Time: 14:39</p>
	<p>1st Wt. for this vehicle: kg Date: Time: 13:34</p>
	<p>Net Wt. for this vehicle: kg</p>
	<hr>
	<h3>Transaction Details:</h3>
	<table>
		<tr>
			<th>MATERIAL</th>
			<th>1st Wt</th>
			<th>2nd Wt</th>
			<th>Net Wt</th>
			<th>Remarks</th>
		</tr>
		<tr>
			<td>DESCRIPTION</td>
			<td>kg</td>
			<td>Kg</td>
			<td>Kg</td>
			<td>Loading</td>
		</tr>
	</table>
	<hr>
	<p>Weighment Completed</p>
	<p>Total Net Wt.: kg</p>
	<p>Charges(1): Rs. 80</p>
	<hr>
	<p>SAVE WATER, SAVE TREES, SAVE FUTURE</p>
	<p>PHONE NO. 7489141848</p>
</body>
</html>
